# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !pip install pytesseract
# !sudo apt-get install tesseract-ocr-ara
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      |████████████████████████████████| 3.2 MB 14.4 MB/s
# ...
#   Attempting uninstall: Pillow
#     Found existing installation: Pillow 7.1.2
#     Uninstalling Pillow-7.1.2:
#       Successfully uninstalled Pillow-7.1.2
# ...
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# The following package was automatically installed and is no longer required:
#   libnvidia-common-460
# Use 'sudo apt autoremove' to remove it.
# The following additional packages will be installed:
#   tesseract-ocr tesseract-ocr-eng tesseract-ocr-osd
# The following NEW packages will be installed:
#   tesseract-ocr tesseract-ocr-ara tesseract-ocr-eng tesseract-ocr-osd
# 0 upgraded, 4 newly installed, 0 to remove and 5 not upgraded.
# Need to get 5,439 kB of archives.
# After this operation, 17.2 MB of additional disk space will be used.
# ...

# %%
import cv2
import numpy as np
from matplotlib import pyplot as plt
from google.colab.patches import cv2_imshow
import pytesseract
from pytesseract import Output
import argparse

# %%
im = cv2.imread("/content/drive/MyDrive/OCR/images/Arabic Fatorah-1.jpg", cv2.IMREAD_COLOR)
plt.rcParams["figure.figsize"] = (10,10)
plt.imshow(im)

plt.show()

# %%
custom_config = r'-l eng+ara --psm 6'
txt = pytesseract.image_to_string("/content/drive/MyDrive/OCR/images/Arabic Fatorah-1.jpg", config=custom_config)
print (txt)
# Out:
# 4 / شباط/ 2022
# الرقم الضريبي 300300600
# فاتورة إلى شحن إلى |
# العميل متاحر الذهبي للأدوات المنزلية المستلم ياسر مسعود
# العنوان الغزاوي . شارع المنصور
# العنوان الزاهر .طريق المدينة المنورة ‎will‏ 966508889206
# مكة المكرمة
# ‎will‏ 966508843212
# استحقاق الدفع 07/نيسان/2022 تاريخ التسليم 28/ ‎blu‏ /2022
# مندوب المبيعات محمد الأحمد وسيلة الشحن السيارة
# شروط الدفع كاش شروط الشحن تسليم باليد
# رقم مجموع ظ
# الكمية ‏ السلعة الوصف سعر الوحدة الخصم الفاتورة
# | 2 | 6 فرن كهربائي 0 رباك لا يوحد 3000
# ‎—__Sewme} ar‏ | _ 2 3 0
# الخصم
# الإحمالي
# الإحمالي 3025
# الفرعي
# ضريبة 453.75
# المبيعات
# شركة أشيد التجارية
# طريق المدينة أمام المتحف الوطني

# %%
im = cv2.imread("/content/drive/MyDrive/OCR/images/ArabicInvoice.png", cv2.IMREAD_COLOR)
plt.rcParams["figure.figsize"] = (10,10)
plt.imshow(im)

plt.show()

# %%
custom_config = r'-l eng+ara --psm 6'
txt = pytesseract.image_to_string("/content/drive/MyDrive/OCR/images/ArabicInvoice.png", config=custom_config)
print (txt)
# Out:
# مؤسسة فضاء البرامج ‎Skysoft Corporation‏
# سكاي سوفت لتقنية المعلومات © ‎For Information Technology‏
# جدة - طريق المدينة بي ‎Jeddah - Al-Madinah Road‏
# هاتف 920002762 ‎www.skysoft.sa SOFT‏
# الرقم الضريبي 111111111111111 111141111111111 ‎Tax Number‏
# ‎A A A‏ لالتلا فاتورة مبيعات ضريبية : [الصفحة _ 1 ‎[aoe‏
# ‏التاريخ: 2021-09-09 النوع: نقد الرقم : 000004 م.التكلفة: المركز الرئيسي - 001
# الموافق: 1443-02-02 الطلبية : المرجع : المندوب :
# الوقت: 12:11 العملة : ريال سعودي الصرف: 1 المستودع : م. الرئيسي - 01
# العميل : برقم ضريبي لايوجد الهاتف :
# العنوان : السائق :
# الوحهة محلي القيد : 000004
# | م | ‎oll tales‏ |الوحدة |الكمية| السعر | الصافي إضربية قيمة مضافة |الصافي+الضريية|
# 11 1 آماءالصفاء 0 أكرتوت ]1.00 20.00 20.00 [2.00[9615_ 22.00 أ
# ‎ts] 2 2‏ أكيرتوت 2.00 220.00 ]440.00 (66.0019615_ 306.00 أ

# %%
im = cv2.imread("/content/drive/MyDrive/OCR/images/Handwritten.jpg", cv2.IMREAD_COLOR)
plt.rcParams["figure.figsize"] = (10,10)
plt.imshow(im)

plt.show()

# %%
txt = pytesseract.image_to_string("/content/drive/MyDrive/OCR/images/Handwritten.jpg", config=custom_config)
print (txt)
# Out:
# فاعام بأث داخملك ميل

# %%
im = cv2.imread("/content/drive/MyDrive/OCR/images/1.jpg")
plt.rcParams["figure.figsize"] = (10,10)
plt.imshow(im[...,::-1])

plt.show()

# %%
txt = pytesseract.image_to_string("/content/drive/MyDrive/OCR/images/1.jpg", config=custom_config)
print (txt)
# Out:
# LT TI rrr rrr ‏١‎
# ‎eT, 1 PTT Terre
# CT ea eee
# i 7 ‏ب ١‎
# (tes Fie ‏ا الل‎
# ‏و‎ a+--+t =
# ee ‏زا‎ [ 4

# %%
im = cv2.imread("/content/drive/MyDrive/OCR/images/2.jpg")
plt.rcParams["figure.figsize"] = (10,10)
plt.imshow(im[...,::-1])
plt.show()

# %%
txt = pytesseract.image_to_string("/content/drive/MyDrive/OCR/images/2.jpg", config=custom_config)
print (txt)
# Out:
# pore s|) Non
# Cre en
# ‏ا واخوات»‎ goa Lava es Lag gs
# elas
# 0138983798 ‏حال 0505818701 اذارةاتولوي  سمو‎
# 1 ‏ظ‎ SU: sc tee 7

# %%
im = cv2.imread("/content/drive/MyDrive/OCR/images/3.jpg")
plt.rcParams["figure.figsize"] = (10,10)
plt.imshow(im[...,::-1])
plt.show()

# %%
txt = pytesseract.image_to_string("/content/drive/MyDrive/OCR/images/3.jpg", config=custom_config)
print (txt)
# Out:
# ‎oe‏ )دا
#
# ‎| ery iar eye
#
# ‎‘Eleanor
# ‎| 77 ‏كد‎ - ٍ
